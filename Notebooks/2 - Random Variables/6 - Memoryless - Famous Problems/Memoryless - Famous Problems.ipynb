# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<div align=center>
# 			<font face="IranNastaliq" size=30>
# 				<p></p>
# 				<p></p>
# به نام خدا
# 				<p></p>
# 			</font>
# 			<font color=#FF7500>
# دانشگاه صنعتی شریف - دانشکده مهندسی کامپیوتر
#             </font>
# 			<p></p>
# 			<font color=blue>
# آمار و احتمال مهندسی
#             </font>
# 			<br />
# 			<br />
# تابستان ۱۳۹۸
# 		</div>
# 		<hr/>
# 		<font color=red size=6>
# 			<br />
# 			<div align=center>
# خاصیت بی‌حافظگی
#             </div>
# 		</font>
# 		<br />
# 		<div align=center>
# رضا یاربخش
#         </div>
# 		<hr />
# 		<style type="text/css" scoped>
#         p{
#         border: 1px solid #a2a9b1;background-color: #f8f9fa;display: inline-block;
#         };
#         </style>
# 		<div>
# 			<h3>فهرست مطالب</h3>
# 			<ul style="margin-right: 0;">
#                 <li>
# 					<a href="#robbery">
#                         سرقت از بانک آهنین
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#bank">
#                         در بانک
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#memorylessness">
#                         بی‌حافظگی
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#escape">
# فرار از بانک
#                     </a>
# 				</li>
#                                 <li>
# 					<a href="#confession">
#                       اعتراف
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#sec_conc">
# خلاصه و نتیجه‌گیری
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#sec_conc">
# منابع
#                     </a>
# 				</li>
# 			</ul>
# 		</div>
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="robbery" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# سرقت از بانک آهنین
#         </font>
# 		<p></p>
# 		<hr>
#   کلثوم که تصور میکرد دستیارهای آموزشی درس آمار پول زیادی از نوشتن جزوه کسب میکنند پس از مشاهده وضعیت مالی تصمیم گرفت راه دیگری برای کسب درآمد پیدا کند. وی که خستگی از ویژگی‌های بارزش بود و همواره به دنبال راه‌های سریع برای پول درآوردن بود تصمیم گرفت به بانک آهنین دستبرد بزند...
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="bank" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# در بانک
#         </font>
# 		<p></p>
# 		<hr>
#         کلثوم پس از ماه‌ها نقشه‌ی دقیقی کشیده و وارد خزانه بانک میشود. خزانه به صورت یک راهروی بسیار طولانی میباشد که در دو طرف آن گاوصندوق‌هایی بر دیوار قرار دارند. رمز هرکدام از گاوصندوق‌ها سه‌رقمیست (عددی تصادفی بین 000 تا 999) و در صورتی که رمز اشتباه وارد شود آن گاوصندوق غیرفعال شده و نمیتوان آن را باز کرد (بنابراین برای هر گاوصندوق تنها یک رمز میتوان امتحان کرد).
#         <img src="figs/safe.JPG" width="500">
#         $$
#         \begin{aligned}
#         \end{aligned}
#         $$
#         کلثوم از ابتدا (گاوصندوق شماره 1) شروع کرده و عدد شانسش(007) را بر روی همه‌ی صندوق‌ها امتحان میکند. اگر متغیر تصادفی $X$ را شماره اولین گاوصندوقی که با این رمز باز میشود در نظر بگیریم، $Pr(X > 1)$ را بیابید.
#         <br />
#                <font color=#29d426>
# پاسخ:
#         </font>
#          متغیر تصادفی $X$ از توزیع هندسی با پارامتر $p=\frac{1}{1000}$ پیروی میکند. بنابراین احتمال این که شماره صندوقی که با این رمز باز میشود بیش از یک باشد برابر با $P(X>1) = \frac{999}{1000}$ میباشد.
#         <br />
#         <br />
#         متاسفانه رمز کلثوم هیچ کدام از 500 گاوصندوق اول را باز نمیکند. اکنون احتمال این که کلثوم نیاز داشته باشد رمز خود را بر روی بیش از یک گاوصندوق دیگر امتحان کند تا به گاوصندوقی با رمز مورد نظر برسد چقدر است؟
#         <br />
#        پاسخ: این به معنی این است که شماره گاوصندوق بازشده بیش از 501 باشد در حالی که میدانیم این عدد از 500 بیشتر است. بنابراین
#         <br />
#         <div style="text-align: left">$P(X > 501 | X > 500) = \frac{P(X > 501)}{P(X > 500)} = \frac{(\frac{999}{1000})^{501}}{(\frac{999}{1000})^{500}} = \frac{999}{1000}$</div>
#             همانطور که مشاهده میکنید این مسئله که رمز 500 گاوصندوق اول عدد شانس کلثوم نبود ارتباطی با احتمال این که کلثوم به بیش از یک تلاش دیگر برای پیدا کردن یک گاوصندوق با رمز مورد نظر داشته باشد نداشت، به چنین ویژگی برای یک متغیر تصادفی بی‌حافظه بودن میگویند.
#              <br />
# 	</font>
# </div>

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=blue size=6>
# کنجکاوی:
#         </font><br/>
#         امید ریاضی اولین صندوقی که با این رمز باز میشود را در دو حالت محاسبه و مقایسه کنید.
#         <br/>
# مسئله را بار دیگر به صورت امتحان کردن رمزهای مختلف بر روی یک گاوصندوق حل کنید. آیا باز هم جواب در دو حالت یکسان است؟
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="memorylessness" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# بی‌حافظگی
#         </font>
# 		<p></p>
# 		<hr>
#         $$
#         \begin{aligned}
#         \end{aligned}
#         $$
# متغیر تصادفی $X$ زمانی بی‌حافظه است که توزیع شرطی احتمال زیر در مورد آن صدق کند:
#         <div style="text-align: left"> $Pr[X > s+t | X > t] = Pr[ X > s], s,t > 0 $ </div>
#         $$
#         \begin{aligned}
#         \end{aligned}
#         $$
# در صورتی که $X$ را به صورت طول عمر یک دستگاه در نظر بگیریم معادله بالا بیانگر آن است که احتمال این که این دستگاه حداقل به اندازه $s + t$ ساعت عمر کند با توجه به این که $t$ ساعت عمر کرده برابر با احتمال اولیه‌ی این است که حداقل $s$ ساعت عمر کند. به بیان دیگر اگر دستگاه در زمان $t$ هنوز سالم باشد توزیع طول عمر باقیمانده‌ی آن همان توزیع طول عمر اولیه‌ی دستگاه میباشد. (دستگاه فراموش میکند که به مدت $t$ استفاده شده است). درواقع بی حافظه بودن به این معناست که رویداد های قبلی تاثیری بر احتمال رویداد های آینده ندارد.
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="escape" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# فرار از بانک
#         </font>
# 		<p></p>
# 		<hr>
#        کلثوم که ماشین ندارد و مسیر بانک را با اسنپ آمده بود حالا شارژ موبایلش تمام شده و مجبور است یکی از ماشین‌های موجود پارکینگ را بردارد. او میداند که طول عمر باتری موجود در ماشین‌های پارکینگ بانک آهنین از توزیع نمایی پیروی میکنند. بر روی باتری هر ماشین میانگین طول عمر آن و بر روی کیلومترشمار آن مسافت طی شده توسط ماشین نوشته شده. با توجه به اطلاعات در دسترس کلثوم چگونه باید ماشینی را انتخاب کند که به احتمال بیشتری بدون تمام شدن باتری در حین فرار بتواند به مقصد برسد؟
#         <br />
#         <font color=#29d426>
# پاسخ:
#         </font>
#          توزیع نمایی یک توزیع بی‌حافظه است. زیرا:
#         <div style="text-align: left"> $Pr[X > s+t | X > t] = \frac{Pr[X > s+t, X > t]}{Pr[x>t]} = \frac{1-F(s+t)}{1-F(t)} = \frac{e^{s+t}}{e^{t}} = e^s = Pr[X > s]$ </div>
#         $$
#         \begin{aligned}
#         \end{aligned}
#         $$
#         بنابراین مسافت طی شده توسط ماشین‌ها اهمیتی ندارد و بر احتمال تمام شدن باتری در طی مسافت $s$ تاثیرگذار نیست. در نتیجه بهترین انتخاب، باتری با میانگین طول عمر بیشتر است هر چند که بیشتر از همه کار کرده باشد.
#         <br />
#         <br />
#                 <font color=#19a887>
#         پ.ن:در دنیای واقعی عمر باتری ماشین از توزیع نمایی پیروی نکرده و با گذر زمان احتمال بقای آن کمتر میشود اما از مثال‌های بی‌حافظگی میتوان به نیمه عمر مواد رادیواکتیو ،زمان کشف بلاک جدید بیت‌کوین و یا زمان رسیدن مشتری بعدی در نظریه‌ی صف اشاره کرد.
#         </font>
# </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="confession" style="direction:rtl;line-height:300%;">
#     <font face="XB Zar" size=5>
#         <font color=#FF7500 size=6>
# اعتراف
#         </font>
#         <p></p>
#         <hr>
# کلثوم که از کرده‌ی خود پشیمان شده تصمیم میگیرد به نزدیکترین پاسگاه مراجعه کرده و خود را تحویل پلیس بدهد. پاسگاه دو منشی دارد که هر دو با توزیع نمایی یکسانی پاسخگو میباشند. زمانی که کلثوم به آنجا میرسد هر دو مشغول اعتراف گرفتن از فرد دیگری هستند و به محض این که اعتراف هر یک تمام شود نوبت به اعتراف کلثوم میرسد. احتمال این که کلثوم آخرین نفری باشد که اعترافش تمام میشود چقدر است؟
#         <br />
#          $$
#         \begin{aligned}
#         \end{aligned}
#         $$
#                <font color=#29d426>
# پاسخ:
#         </font>
#         از آن جا که توزیع نمایی بی حافظه است زمانی که نفر اول اعترافش تمام شود مانند این است که کلثوم و فرد دیگر با توزیع یکسانی همزمان شروع به اعتراف کرده‌اند. پس احتمال این که اعتراف کلثوم دیرتر تمام شود برابر با $\frac{1}{2}$ میباشد.
#         <br />
#         <br />
#         <font color=red>
#         تمرین:
#             </font><br />
#         <li>قطعه کد زیر را تکمیل کنید و با استفاده از آن پاسخ مسئله بالا را به دست آورید. (همچنین میتوانید با رسم نموار زمان پایان اعترف مجرم دیگر که همزمان با کلثوم در حال اعتراف است از زمانی که کلثوم شروع به اعتراف میکند به پیروی آن از همان توزیع نمایی اصلی پی ببرید)
#         </li>
#        </font>
# </div>

# %%
lambda = 2 #arbitary
first_confession_time = rexp(10000,lambda)
second_confession_time = rexp(10000,lambda)
colsum_confession_time = rexp(10000,lambda)
#calculate finish times and the probability that colsum's finish time is the last finish time

# %% [markdown]
# <p></p>
# <br />
# <div id="memorylessness" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# فروشگاه بی حافظه
#         </font>
# 		<p></p>
# 		<hr>
#         $$
#         \begin{aligned}
#         \end{aligned}
#         $$
# فرض کنید یک فروشگاه داریم که در هر ساعت به صورت میانگین ۳۰ مشتری وارد فروشگاه می شوند به طوری که زمان بین هر دو ورود از یک تابع نمایی پیروی می کند و بین هر دو ورود به صورت میانگین ۲ دقیقه طول می کشد.
#         حال اگر از زمانی که مشتری قبلی وارد شده است، ۱۰ دقیقه گذشته باشد به صورت شهودی به نظر می رسد که در یک دقیقه ی آینده خیلی احتمال دارد که یک مشتری وارد فروشگاه شود.
#         از طرفی به دلیل خاصیت بی حافظگی تابع نمایی مهم نیست از زمان ورود مشتری قبل چقدر گذشته باشد و به همین دلیل شهود ما نادرست است.
#         حال به کمک $CDF$ توزیع نمایی می توان این حقیقت را اثبات نمود:
#         $$
#         \begin{aligned}
#         \end{aligned}
#         $$
#         <div style="text-align: left"> $CDF: 1-e^{-st}$ </div>
#         $$
#         \begin{aligned}
#         \end{aligned}
#         $$
#         در حالی که $s$ به صورت ۱ تقسیم بر زمان بین دو ورود تعریف می شود و داریم:
#         $$
#         \begin{aligned}
#         \end{aligned}
#         $$
#         <div style="text-align: left"> $s = \frac{1}{2}=0.5$ </div>
#         $$
#         \begin{aligned}
#         \end{aligned}
#         $$
#         که خواهیم داشت:
#         $$
#         \begin{aligned}
#         \end{aligned}
#         $$
#         <div style="text-align: left"> $Pr[X > 10+1 | X >= 10] = Pr[X > 1] = 1 - (1 - e^{(-0.5)(1)}) = 0.6065$ </div>
#         $$
#         \begin{aligned}
#         \end{aligned}
#         $$
#         به این ترتیب فارغ از اینکه مشتری در ده دقیقه ی گذشته هیچ مشتری ای وارد فروشگاه نشده است، چون توزیع ورود مشتریان به صورت نمایی است احتمال اینکه در یک دقیقه آینده یک مشتری به فروشگاه وارد شود حساب می شود.
#        $$
#         \begin{aligned}
#         \end{aligned}
#         $$
# 	</font>
# </div>

# %% [markdown]
# <div id="sec_jam_again" style="direction:rtl;line-height:300%;">
#     <font face="XB Zar" size=5>
#          <font color=red>
#         تمرین:
#             </font><br />
#         <li>
#          توزیع هندسی (گسسته) و توزیع نمایی (پیوسته) تنها توزیع‌های بی‌حافظه میباشند. سعی کنید یکتایی آن‌ها را اثبات کنید.
#         </li>
#     </font>
# </div>

# %% [markdown]
# <p></p>
# <br/>
# <div id="sec_conc" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# خلاصه و نتیجه‌گیری
#         </font>
# 		<p></p>
# 		<hr>
#         در این بخش با موارد زیر آشنا شدیم:
#         <ul>
#             <li>
#            ویژگی بی‌حافظگی در توزیع‌ها و چند مثال از کاربرد آن
#             </li>
#             <li>
#             دو نوع توزیع بی‌حافظه و یکتایی آنها
#             </li>
#             <li>
#             فروشگاه ها حافظه ندارند :)
#             </li>
#             <li>
#             عاقبت دزدی :|
#             </li>
#         </ul>
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br/>
# <div id="sec_refs" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# منابع
#         </font>
# 		<hr>
#         <ul>
#             <li>
#                 George R. R. Martin's A Song of Ice and Fire
#             </li>
#             <li>
#                 Feller, W. (1971) Introduction to Probability Theory and Its Applications, Vol II (2nd edition),Wiley.
#             </li>
#             <li>
#                 Ross, Sheldon M. (2010). A First course in Probability (8th ed.). Pearson Prentice Hall.
#             </li>
#             <li>
#                 https://en.wikipedia.org/wiki/Memorylessness
#             </li>
#             <li>
# R Core Team (2018). R: A language and envronment for statistical
#   computing. R Foundation for Statistical Computing, Vienna, Austria.
#   URL https://www.R-project.org/.
#             </li>
#         </ul>
# 	</font>
# </div>
